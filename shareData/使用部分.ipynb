# %% [markdown]
# # 导入包

# %%
import numpy as np
from multiprocessing import shared_memory
import pandas as pd
from ShareData import ShareDataFrame

# %% [markdown]
# # 使用数据

# %%
sdf = ShareDataFrame()
data = sdf.memory2df()
sdf.close_read()
data
# Out:
# [['CRIM', 'psm_85f03df7'], ['ZN', 'psm_5570d94c'], ['INDUS', 'psm_704ef2f0'], ['CHAS', 'psm_18d81451'], ['NOX', 'psm_6f323b74'], ['RM', 'psm_21c0f824'], ['AGE', 'psm_9ca8058f'], ['DIS', 'psm_a2e9e3b1'], ['RAD', 'psm_80c36b7b'], ['TAX', 'psm_552f2c44'], ['PTRATIO', 'psm_37e4bac2'], ['B', 'psm_1a4e6a77'], ['LSTAT', 'psm_780170d9']]
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# ...

# %%
import numpy as np
from multiprocessing import shared_memory
import pandas as pd
from ShareData import ShareDataFrame

sdf = ShareDataFrame()
data = sdf.memory2df()
data
